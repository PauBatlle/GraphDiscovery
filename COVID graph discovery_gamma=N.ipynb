# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
from newGraphDiscovery import GraphDiscoveryNew
from Modes import ModeContainer
import numpy as onp
import matplotlib.pyplot as plt
import networkx as nx

# %% [markdown]
# # Study all available data

# %%
df=pd.read_csv("france_covid_data.csv")
df=df.drop("date",axis=1)
df
# Out:
#      new_hospitalized_patients  cumulative_hospitalized_patients  \
# 0                        589.0                          272296.0
# 1                       1217.0                          273513.0
# 2                       1627.0                          275140.0
# 3                       1404.0                          276544.0
# 4                       1317.0                          277861.0
# ..                         ...                               ...
# 502                      756.0                          822964.0
# 503                      387.0                          823351.0
# 504                      145.0                          823496.0
# 505                      900.0                          824396.0
# 506                      883.0                          825279.0
#
#      current_hospitalized_patients  new_intensive_care_patients  \
# 0                          24620.0                        107.0
# 1                          24645.0                        229.0
# 2                          24743.0                        251.0
# 3                          24560.0                        209.0
# 4                          24407.0                        177.0
# ..                             ...                          ...
# 502                        19272.0                         77.0
# 503                        18901.0                         42.0
# 504                        18935.0                         13.0
# 505                        18742.0                         94.0
# 506                        18290.0                        106.0
#
#      cumulative_intensive_care_patients  current_intensive_care_patients  \
# 0                               42622.0                           2650.0
# 1                               42851.0                           2694.0
# 2                               43102.0                           2666.0
# 3                               43311.0                           2652.0
# 4                               43488.0                           2625.0
# ..                                  ...                              ...
# 502                            136447.0                           1233.0
# 503                            136489.0                           1213.0
# 504                            136502.0                           1214.0
# 505                            136596.0                           1199.0
# 506                            136702.0                           1173.0
#
#      school_closing  workplace_closing  cancel_public_events  \
# 0               2.0                2.0                   2.0
# 1               2.0                2.0                   2.0
# 2               2.0                2.0                   2.0
# 3               2.0                2.0                   2.0
# 4               2.0                2.0                   2.0
# ..              ...                ...                   ...
# 502             0.0                1.0                   0.0
# 503             0.0                1.0                   0.0
# 504             0.0                1.0                   0.0
# 505             0.0                1.0                   0.0
# 506             0.0                1.0                   0.0
#
#      restrictions_on_gatherings  ...  cumulative_confirmed  \
# 0                           4.0  ...             2556944.0
# 1                           4.0  ...             2559904.0
# 2                           4.0  ...             2571299.0
# 3                           4.0  ...             2597756.0
# 4                           4.0  ...             2617683.0
# ..                          ...  ...                   ...
# 502                         0.0  ...             3558022.0
# 503                         0.0  ...             3558022.0
# 504                         0.0  ...             3558022.0
# 505                         0.0  ...             3558022.0
# 506                         0.0  ...             3558022.0
#
#      cumulative_deceased  cumulative_recovered  cumulative_tested  \
# 0                43551.0            25148369.0         34726580.0
# 1                43914.0            25339091.0         35124318.0
# 2                44298.0            25530897.0         35490439.0
# 3                44601.0            25723942.0         35889993.0
# 4                44852.0            25918163.0         36227201.0
# ..                   ...                   ...                ...
# 502             147257.0           231965820.0        272612209.0
# 503             147331.0           232619554.0        272775929.0
# 504             147352.0           233273381.0        272775929.0
# 505             147478.0           233928156.0        272775929.0
# 506             147568.0           234584140.0        272775929.0
#
#      new_persons_vaccinated  cumulative_persons_vaccinated  \
# 0                     609.0                          609.0
# 1                     683.0                         1292.0
# 2                     384.0                         1676.0
# 3                     443.0                         2119.0
# 4                     440.0                         2559.0
# ..                      ...                            ...
# 502                  1957.0                     54446241.0
# 503                  1143.0                     54447384.0
# 504                   280.0                     54447664.0
# 505                  1178.0                     54448842.0
# 506                  1568.0                     54450410.0
#
#      new_persons_fully_vaccinated  cumulative_persons_fully_vaccinated  \
# 0                            55.0                                 55.0
# 1                            42.0                                 97.0
# 2                            19.0                                116.0
# 3                            18.0                                134.0
# 4                            23.0                                157.0
# ..                            ...                                  ...
# 502                        2027.0                           53539427.0
# 503                        1169.0                           53540596.0
# 504                         279.0                           53540875.0
# 505                        1206.0                           53542081.0
# 506                        1622.0                           53543703.0
#
#      new_vaccine_doses_administered  cumulative_vaccine_doses_administered
# 0                             664.0                                  664.0
# 1                             725.0                                 1389.0
# 2                             403.0                                 1792.0
# 3                             461.0                                 2253.0
# 4                             463.0                                 2716.0
# ..                              ...                                    ...
# 502                          3984.0                            107985668.0
# 503                          2312.0                            107987980.0
# 504                           559.0                            107988539.0
# 505                          2384.0                            107990923.0
# 506                          3190.0                            107994113.0
#
# [507 rows x 31 columns]

# %%
node_names=df.columns
X=df.to_numpy()
X=(X-onp.mean(X,axis=0))/onp.std(X,axis=0)

# %%
modes=ModeContainer.make_container(
    X.T,
    onp.array(node_names),
    {'name':'linear','beta':0.1,'type':'individual','interpolatory':False,'default':True},
    {'name':'quadratic','beta':0.01,'type':'pairwise','interpolatory':False,'default':True},
)

# %%
graph_discovery=GraphDiscoveryNew(X.T,onp.array(node_names),modes)

# %%
for node in graph_discovery.names:
    print(f'inspecting {node}')
    graph_discovery.find_ancestors(
        node,
        gamma='auto',
    )
    print('\n')
# Out:
# inspecting new_hospitalized_patients
# linear kernel (using gamma=5.07e+02)
#  n/(n+s)=0.78, Z=0.99
# quadratic kernel (using gamma=5.07e+02)
#  n/(n+s)=0.71, Z=0.99
# new_hospitalized_patients has ancestors with quadratic kernel (n/(s+n)=0.71)
# ancestors : ['cumulative_hospitalized_patients', 'current_hospitalized_patients', 'new_intensive_care_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'school_closing', 'cancel_public_events', 'restrictions_on_gatherings', 'public_transport_closing', 'stay_at_home_requirements', 'restrictions_on_internal_movement', 'income_support', 'facial_coverings', 'vaccination_policy', 'stringency_index', 'new_confirmed', 'new_deceased', 'new_recovered', 'new_tested', 'cumulative_confirmed', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'new_persons_vaccinated', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated', 'new_vaccine_doses_administered', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.71, Z=0.99
# ancestors : ['cumulative_hospitalized_patients', 'current_hospitalized_patients', 'new_intensive_care_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'school_closing', 'cancel_public_events', 'restrictions_on_gatherings', 'public_transport_closing', 'stay_at_home_requirements', 'restrictions_on_internal_movement', 'income_support', 'facial_coverings', 'vaccination_policy', 'stringency_index', 'new_confirmed', 'new_deceased', 'new_recovered', 'new_tested', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'new_persons_vaccinated', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated', 'new_vaccine_doses_administered', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.72, Z=0.99
# ancestors : ['cumulative_hospitalized_patients', 'current_hospitalized_patients', 'new_intensive_care_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'school_closing', 'restrictions_on_gatherings', 'public_transport_closing', 'stay_at_home_requirements', 'restrictions_on_internal_movement', 'income_support', 'facial_coverings', 'vaccination_policy', 'stringency_index', 'new_confirmed', 'new_deceased', 'new_recovered', 'new_tested', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'new_persons_vaccinated', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated', 'new_vaccine_doses_administered', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.72, Z=0.99
# ancestors : ['cumulative_hospitalized_patients', 'current_hospitalized_patients', 'new_intensive_care_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'school_closing', 'restrictions_on_gatherings', 'public_transport_closing', 'stay_at_home_requirements', 'restrictions_on_internal_movement', 'facial_coverings', 'vaccination_policy', 'stringency_index', 'new_confirmed', 'new_deceased', 'new_recovered', 'new_tested', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'new_persons_vaccinated', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated', 'new_vaccine_doses_administered', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.72, Z=0.99
# ancestors : ['cumulative_hospitalized_patients', 'current_hospitalized_patients', 'new_intensive_care_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'restrictions_on_gatherings', 'public_transport_closing', 'stay_at_home_requirements', 'restrictions_on_internal_movement', 'facial_coverings', 'vaccination_policy', 'stringency_index', 'new_confirmed', 'new_deceased', 'new_recovered', 'new_tested', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'new_persons_vaccinated', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated', 'new_vaccine_doses_administered', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.72, Z=0.99
# ancestors : ['cumulative_hospitalized_patients', 'current_hospitalized_patients', 'new_intensive_care_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'restrictions_on_gatherings', 'public_transport_closing', 'stay_at_home_requirements', 'restrictions_on_internal_movement', 'facial_coverings', 'vaccination_policy', 'new_confirmed', 'new_deceased', 'new_recovered', 'new_tested', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'new_persons_vaccinated', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated', 'new_vaccine_doses_administered', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.72, Z=0.99
# ancestors : ['cumulative_hospitalized_patients', 'current_hospitalized_patients', 'new_intensive_care_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'public_transport_closing', 'stay_at_home_requirements', 'restrictions_on_internal_movement', 'facial_coverings', 'vaccination_policy', 'new_confirmed', 'new_deceased', 'new_recovered', 'new_tested', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'new_persons_vaccinated', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated', 'new_vaccine_doses_administered', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.72, Z=0.99
# ancestors : ['cumulative_hospitalized_patients', 'current_hospitalized_patients', 'new_intensive_care_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'public_transport_closing', 'stay_at_home_requirements', 'restrictions_on_internal_movement', 'vaccination_policy', 'new_confirmed', 'new_deceased', 'new_recovered', 'new_tested', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'new_persons_vaccinated', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated', 'new_vaccine_doses_administered', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.72, Z=0.99
# ancestors : ['cumulative_hospitalized_patients', 'current_hospitalized_patients', 'new_intensive_care_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'stay_at_home_requirements', 'restrictions_on_internal_movement', 'vaccination_policy', 'new_confirmed', 'new_deceased', 'new_recovered', 'new_tested', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'new_persons_vaccinated', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated', 'new_vaccine_doses_administered', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.72, Z=0.99
# ancestors : ['cumulative_hospitalized_patients', 'current_hospitalized_patients', 'new_intensive_care_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'stay_at_home_requirements', 'restrictions_on_internal_movement', 'vaccination_policy', 'new_confirmed', 'new_deceased', 'new_recovered', 'new_tested', 'cumulative_recovered', 'cumulative_tested', 'new_persons_vaccinated', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated', 'new_vaccine_doses_administered', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.73, Z=0.99
# ancestors : ['cumulative_hospitalized_patients', 'current_hospitalized_patients', 'new_intensive_care_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'stay_at_home_requirements', 'restrictions_on_internal_movement', 'vaccination_policy', 'new_confirmed', 'new_deceased', 'new_recovered', 'new_tested', 'cumulative_recovered', 'cumulative_tested', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated', 'new_vaccine_doses_administered', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.73, Z=0.99
# ancestors : ['cumulative_hospitalized_patients', 'current_hospitalized_patients', 'new_intensive_care_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'restrictions_on_internal_movement', 'vaccination_policy', 'new_confirmed', 'new_deceased', 'new_recovered', 'new_tested', 'cumulative_recovered', 'cumulative_tested', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated', 'new_vaccine_doses_administered', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.73, Z=0.99
# ancestors : ['cumulative_hospitalized_patients', 'current_hospitalized_patients', 'new_intensive_care_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'restrictions_on_internal_movement', 'vaccination_policy', 'new_confirmed', 'new_deceased', 'new_tested', 'cumulative_recovered', 'cumulative_tested', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated', 'new_vaccine_doses_administered', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.73, Z=0.99
# ancestors : ['cumulative_hospitalized_patients', 'current_hospitalized_patients', 'new_intensive_care_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'vaccination_policy', 'new_confirmed', 'new_deceased', 'new_tested', 'cumulative_recovered', 'cumulative_tested', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated', 'new_vaccine_doses_administered', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.73, Z=0.99
# ancestors : ['cumulative_hospitalized_patients', 'current_hospitalized_patients', 'new_intensive_care_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'vaccination_policy', 'new_confirmed', 'new_deceased', 'new_tested', 'cumulative_recovered', 'cumulative_tested', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'new_vaccine_doses_administered', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.74, Z=0.99
# ancestors : ['cumulative_hospitalized_patients', 'current_hospitalized_patients', 'new_intensive_care_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'vaccination_policy', 'new_confirmed', 'new_deceased', 'new_tested', 'cumulative_recovered', 'cumulative_tested', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'new_vaccine_doses_administered']
#  n/(n+s)=0.74, Z=0.99
# ancestors : ['current_hospitalized_patients', 'new_intensive_care_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'vaccination_policy', 'new_confirmed', 'new_deceased', 'new_tested', 'cumulative_recovered', 'cumulative_tested', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'new_vaccine_doses_administered']
#  n/(n+s)=0.74, Z=0.99
# ancestors : ['current_hospitalized_patients', 'new_intensive_care_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'vaccination_policy', 'new_confirmed', 'new_deceased', 'new_tested', 'cumulative_tested', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'new_vaccine_doses_administered']
#  n/(n+s)=0.75, Z=0.99
# ancestors : ['current_hospitalized_patients', 'new_intensive_care_patients', 'current_intensive_care_patients', 'vaccination_policy', 'new_confirmed', 'new_deceased', 'new_tested', 'cumulative_tested', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'new_vaccine_doses_administered']
#  n/(n+s)=0.75, Z=0.99
# ancestors : ['current_hospitalized_patients', 'new_intensive_care_patients', 'current_intensive_care_patients', 'vaccination_policy', 'new_confirmed', 'new_deceased', 'new_tested', 'cumulative_tested', 'new_persons_fully_vaccinated', 'new_vaccine_doses_administered']
#  n/(n+s)=0.75, Z=0.99
# ancestors : ['current_hospitalized_patients', 'new_intensive_care_patients', 'current_intensive_care_patients', 'vaccination_policy', 'new_confirmed', 'new_deceased', 'new_tested', 'cumulative_tested', 'new_persons_fully_vaccinated']
#  n/(n+s)=0.76, Z=1.00
# ancestors : ['current_hospitalized_patients', 'new_intensive_care_patients', 'current_intensive_care_patients', 'new_confirmed', 'new_deceased', 'new_tested', 'cumulative_tested', 'new_persons_fully_vaccinated']
#  n/(n+s)=0.76, Z=1.00
# ancestors : ['current_hospitalized_patients', 'new_intensive_care_patients', 'current_intensive_care_patients', 'new_confirmed', 'new_deceased', 'new_tested', 'new_persons_fully_vaccinated']
#  n/(n+s)=0.77, Z=1.00
# ancestors : ['current_hospitalized_patients', 'new_intensive_care_patients', 'current_intensive_care_patients', 'new_confirmed', 'new_deceased', 'new_tested']
#  n/(n+s)=0.77, Z=1.00
# ancestors : ['current_hospitalized_patients', 'new_intensive_care_patients', 'new_confirmed', 'new_deceased', 'new_tested']
#  n/(n+s)=0.79, Z=1.00
# ancestors : ['current_hospitalized_patients', 'new_intensive_care_patients', 'new_confirmed', 'new_deceased']
#  n/(n+s)=0.81, Z=1.00
# ancestors : ['new_intensive_care_patients', 'new_confirmed', 'new_deceased']
#  n/(n+s)=0.84, Z=1.00
# ancestors : ['new_intensive_care_patients', 'new_deceased']
#  n/(n+s)=0.89, Z=1.00
# ancestors : ['new_intensive_care_patients']
#  n/(n+s)=0.94, Z=1.00
# ancestors after pruning:  ['new_intensive_care_patients']
#
#
#
# inspecting cumulative_hospitalized_patients
# linear kernel (using gamma=5.07e+02)
#  n/(n+s)=0.50, Z=0.99
# quadratic kernel (using gamma=5.07e+02)
#  n/(n+s)=0.42, Z=0.99
# cumulative_hospitalized_patients has ancestors with quadratic kernel (n/(s+n)=0.42)
# ancestors : ['new_hospitalized_patients', 'current_hospitalized_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'school_closing', 'workplace_closing', 'cancel_public_events', 'restrictions_on_gatherings', 'public_transport_closing', 'stay_at_home_requirements', 'restrictions_on_internal_movement', 'income_support', 'facial_coverings', 'vaccination_policy', 'stringency_index', 'new_confirmed', 'new_deceased', 'new_recovered', 'new_tested', 'cumulative_confirmed', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'new_persons_vaccinated', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated', 'new_vaccine_doses_administered', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.42, Z=0.99
# ancestors : ['new_hospitalized_patients', 'current_hospitalized_patients', 'cumulative_intensive_care_patients', 'school_closing', 'workplace_closing', 'cancel_public_events', 'restrictions_on_gatherings', 'public_transport_closing', 'stay_at_home_requirements', 'restrictions_on_internal_movement', 'income_support', 'facial_coverings', 'vaccination_policy', 'stringency_index', 'new_confirmed', 'new_deceased', 'new_recovered', 'new_tested', 'cumulative_confirmed', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'new_persons_vaccinated', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated', 'new_vaccine_doses_administered', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.42, Z=0.99
# ancestors : ['new_hospitalized_patients', 'current_hospitalized_patients', 'cumulative_intensive_care_patients', 'school_closing', 'workplace_closing', 'cancel_public_events', 'restrictions_on_gatherings', 'public_transport_closing', 'stay_at_home_requirements', 'restrictions_on_internal_movement', 'income_support', 'facial_coverings', 'vaccination_policy', 'stringency_index', 'new_confirmed', 'new_deceased', 'new_recovered', 'cumulative_confirmed', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'new_persons_vaccinated', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated', 'new_vaccine_doses_administered', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.42, Z=0.99
# ancestors : ['current_hospitalized_patients', 'cumulative_intensive_care_patients', 'school_closing', 'workplace_closing', 'cancel_public_events', 'restrictions_on_gatherings', 'public_transport_closing', 'stay_at_home_requirements', 'restrictions_on_internal_movement', 'income_support', 'facial_coverings', 'vaccination_policy', 'stringency_index', 'new_confirmed', 'new_deceased', 'new_recovered', 'cumulative_confirmed', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'new_persons_vaccinated', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated', 'new_vaccine_doses_administered', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.42, Z=0.99
# ancestors : ['current_hospitalized_patients', 'cumulative_intensive_care_patients', 'school_closing', 'workplace_closing', 'cancel_public_events', 'restrictions_on_gatherings', 'public_transport_closing', 'stay_at_home_requirements', 'restrictions_on_internal_movement', 'income_support', 'facial_coverings', 'vaccination_policy', 'stringency_index', 'new_deceased', 'new_recovered', 'cumulative_confirmed', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'new_persons_vaccinated', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated', 'new_vaccine_doses_administered', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.43, Z=0.99
# ancestors : ['current_hospitalized_patients', 'cumulative_intensive_care_patients', 'school_closing', 'workplace_closing', 'cancel_public_events', 'restrictions_on_gatherings', 'public_transport_closing', 'stay_at_home_requirements', 'income_support', 'facial_coverings', 'vaccination_policy', 'stringency_index', 'new_deceased', 'new_recovered', 'cumulative_confirmed', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'new_persons_vaccinated', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated', 'new_vaccine_doses_administered', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.43, Z=0.99
# ancestors : ['current_hospitalized_patients', 'cumulative_intensive_care_patients', 'school_closing', 'workplace_closing', 'cancel_public_events', 'restrictions_on_gatherings', 'public_transport_closing', 'stay_at_home_requirements', 'income_support', 'facial_coverings', 'vaccination_policy', 'stringency_index', 'new_recovered', 'cumulative_confirmed', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'new_persons_vaccinated', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated', 'new_vaccine_doses_administered', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.44, Z=0.99
# ancestors : ['current_hospitalized_patients', 'cumulative_intensive_care_patients', 'school_closing', 'workplace_closing', 'cancel_public_events', 'restrictions_on_gatherings', 'public_transport_closing', 'stay_at_home_requirements', 'income_support', 'facial_coverings', 'vaccination_policy', 'stringency_index', 'new_recovered', 'cumulative_confirmed', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated', 'new_vaccine_doses_administered', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.44, Z=0.99
# ancestors : ['current_hospitalized_patients', 'cumulative_intensive_care_patients', 'school_closing', 'workplace_closing', 'cancel_public_events', 'restrictions_on_gatherings', 'public_transport_closing', 'stay_at_home_requirements', 'income_support', 'facial_coverings', 'vaccination_policy', 'stringency_index', 'new_recovered', 'cumulative_confirmed', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'cumulative_persons_vaccinated', 'cumulative_persons_fully_vaccinated', 'new_vaccine_doses_administered', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.45, Z=0.99
# ancestors : ['current_hospitalized_patients', 'cumulative_intensive_care_patients', 'school_closing', 'workplace_closing', 'cancel_public_events', 'restrictions_on_gatherings', 'public_transport_closing', 'stay_at_home_requirements', 'income_support', 'facial_coverings', 'vaccination_policy', 'stringency_index', 'new_recovered', 'cumulative_confirmed', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'cumulative_persons_vaccinated', 'cumulative_persons_fully_vaccinated', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.46, Z=0.99
# ancestors : ['current_hospitalized_patients', 'cumulative_intensive_care_patients', 'school_closing', 'workplace_closing', 'cancel_public_events', 'restrictions_on_gatherings', 'stay_at_home_requirements', 'income_support', 'facial_coverings', 'vaccination_policy', 'stringency_index', 'new_recovered', 'cumulative_confirmed', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'cumulative_persons_vaccinated', 'cumulative_persons_fully_vaccinated', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.46, Z=0.99
# ancestors : ['current_hospitalized_patients', 'cumulative_intensive_care_patients', 'school_closing', 'workplace_closing', 'cancel_public_events', 'restrictions_on_gatherings', 'stay_at_home_requirements', 'income_support', 'facial_coverings', 'vaccination_policy', 'stringency_index', 'new_recovered', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'cumulative_persons_vaccinated', 'cumulative_persons_fully_vaccinated', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.46, Z=1.00
# ancestors : ['current_hospitalized_patients', 'cumulative_intensive_care_patients', 'school_closing', 'workplace_closing', 'cancel_public_events', 'restrictions_on_gatherings', 'stay_at_home_requirements', 'income_support', 'facial_coverings', 'vaccination_policy', 'new_recovered', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'cumulative_persons_vaccinated', 'cumulative_persons_fully_vaccinated', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.47, Z=1.00
# ancestors : ['cumulative_intensive_care_patients', 'school_closing', 'workplace_closing', 'cancel_public_events', 'restrictions_on_gatherings', 'stay_at_home_requirements', 'income_support', 'facial_coverings', 'vaccination_policy', 'new_recovered', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'cumulative_persons_vaccinated', 'cumulative_persons_fully_vaccinated', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.48, Z=1.00
# ancestors : ['cumulative_intensive_care_patients', 'school_closing', 'workplace_closing', 'cancel_public_events', 'restrictions_on_gatherings', 'income_support', 'facial_coverings', 'vaccination_policy', 'new_recovered', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'cumulative_persons_vaccinated', 'cumulative_persons_fully_vaccinated', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.49, Z=1.00
# ancestors : ['cumulative_intensive_care_patients', 'school_closing', 'workplace_closing', 'cancel_public_events', 'restrictions_on_gatherings', 'income_support', 'vaccination_policy', 'new_recovered', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'cumulative_persons_vaccinated', 'cumulative_persons_fully_vaccinated', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.50, Z=1.00
# ancestors : ['cumulative_intensive_care_patients', 'school_closing', 'cancel_public_events', 'restrictions_on_gatherings', 'income_support', 'vaccination_policy', 'new_recovered', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'cumulative_persons_vaccinated', 'cumulative_persons_fully_vaccinated', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.50, Z=1.00
# ancestors : ['cumulative_intensive_care_patients', 'cancel_public_events', 'restrictions_on_gatherings', 'income_support', 'vaccination_policy', 'new_recovered', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'cumulative_persons_vaccinated', 'cumulative_persons_fully_vaccinated', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.51, Z=1.00
# ancestors : ['cumulative_intensive_care_patients', 'cancel_public_events', 'restrictions_on_gatherings', 'income_support', 'vaccination_policy', 'new_recovered', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'cumulative_persons_vaccinated', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.53, Z=1.00
# ancestors : ['cumulative_intensive_care_patients', 'restrictions_on_gatherings', 'income_support', 'vaccination_policy', 'new_recovered', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'cumulative_persons_vaccinated', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.55, Z=1.00
# ancestors : ['cumulative_intensive_care_patients', 'restrictions_on_gatherings', 'income_support', 'vaccination_policy', 'new_recovered', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'cumulative_persons_vaccinated']
#  n/(n+s)=0.56, Z=1.00
# ancestors : ['cumulative_intensive_care_patients', 'restrictions_on_gatherings', 'income_support', 'new_recovered', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'cumulative_persons_vaccinated']
#  n/(n+s)=0.59, Z=1.00
# ancestors : ['cumulative_intensive_care_patients', 'income_support', 'new_recovered', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'cumulative_persons_vaccinated']
#  n/(n+s)=0.61, Z=1.00
# ancestors : ['cumulative_intensive_care_patients', 'income_support', 'new_recovered', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested']
#  n/(n+s)=0.64, Z=1.00
# ancestors : ['cumulative_intensive_care_patients', 'new_recovered', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested']
#  n/(n+s)=0.68, Z=1.00
# ancestors : ['cumulative_intensive_care_patients', 'new_recovered', 'cumulative_recovered', 'cumulative_tested']
#  n/(n+s)=0.72, Z=1.00
# ancestors : ['cumulative_intensive_care_patients', 'new_recovered', 'cumulative_recovered']
#  n/(n+s)=0.77, Z=1.00
# ancestors : ['cumulative_intensive_care_patients', 'new_recovered']
#  n/(n+s)=0.84, Z=1.00
# ancestors : ['new_recovered']
#  n/(n+s)=0.91, Z=1.00
# ancestors after pruning:  ['new_recovered']
#
#
#
# inspecting current_hospitalized_patients
# linear kernel (using gamma=5.07e+02)
#  n/(n+s)=0.78, Z=0.99
# quadratic kernel (using gamma=5.07e+02)
#  n/(n+s)=0.69, Z=0.99
# current_hospitalized_patients has ancestors with quadratic kernel (n/(s+n)=0.69)
# ancestors : ['new_hospitalized_patients', 'cumulative_hospitalized_patients', 'new_intensive_care_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'school_closing', 'workplace_closing', 'cancel_public_events', 'restrictions_on_gatherings', 'public_transport_closing', 'stay_at_home_requirements', 'restrictions_on_internal_movement', 'income_support', 'facial_coverings', 'vaccination_policy', 'stringency_index', 'new_confirmed', 'new_deceased', 'new_recovered', 'cumulative_confirmed', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'new_persons_vaccinated', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated', 'new_vaccine_doses_administered', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.69, Z=0.99
# ancestors : ['new_hospitalized_patients', 'cumulative_hospitalized_patients', 'new_intensive_care_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'school_closing', 'workplace_closing', 'cancel_public_events', 'restrictions_on_gatherings', 'public_transport_closing', 'stay_at_home_requirements', 'restrictions_on_internal_movement', 'income_support', 'facial_coverings', 'vaccination_policy', 'stringency_index', 'new_confirmed', 'new_deceased', 'new_recovered', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'new_persons_vaccinated', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated', 'new_vaccine_doses_administered', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.69, Z=0.99
# ancestors : ['new_hospitalized_patients', 'cumulative_hospitalized_patients', 'new_intensive_care_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'school_closing', 'cancel_public_events', 'restrictions_on_gatherings', 'public_transport_closing', 'stay_at_home_requirements', 'restrictions_on_internal_movement', 'income_support', 'facial_coverings', 'vaccination_policy', 'stringency_index', 'new_confirmed', 'new_deceased', 'new_recovered', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'new_persons_vaccinated', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated', 'new_vaccine_doses_administered', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.69, Z=0.99
# ancestors : ['new_hospitalized_patients', 'cumulative_hospitalized_patients', 'new_intensive_care_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'school_closing', 'restrictions_on_gatherings', 'public_transport_closing', 'stay_at_home_requirements', 'restrictions_on_internal_movement', 'income_support', 'facial_coverings', 'vaccination_policy', 'stringency_index', 'new_confirmed', 'new_deceased', 'new_recovered', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'new_persons_vaccinated', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated', 'new_vaccine_doses_administered', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.70, Z=0.99
# ancestors : ['new_hospitalized_patients', 'cumulative_hospitalized_patients', 'new_intensive_care_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'school_closing', 'restrictions_on_gatherings', 'public_transport_closing', 'stay_at_home_requirements', 'restrictions_on_internal_movement', 'income_support', 'facial_coverings', 'vaccination_policy', 'stringency_index', 'new_confirmed', 'new_deceased', 'new_recovered', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated', 'new_vaccine_doses_administered', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.70, Z=0.99
# ancestors : ['new_hospitalized_patients', 'cumulative_hospitalized_patients', 'new_intensive_care_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'school_closing', 'restrictions_on_gatherings', 'public_transport_closing', 'stay_at_home_requirements', 'income_support', 'facial_coverings', 'vaccination_policy', 'stringency_index', 'new_confirmed', 'new_deceased', 'new_recovered', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated', 'new_vaccine_doses_administered', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.70, Z=0.99
# ancestors : ['new_hospitalized_patients', 'cumulative_hospitalized_patients', 'new_intensive_care_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'school_closing', 'public_transport_closing', 'stay_at_home_requirements', 'income_support', 'facial_coverings', 'vaccination_policy', 'stringency_index', 'new_confirmed', 'new_deceased', 'new_recovered', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated', 'new_vaccine_doses_administered', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.70, Z=0.99
# ancestors : ['new_hospitalized_patients', 'cumulative_hospitalized_patients', 'new_intensive_care_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'school_closing', 'public_transport_closing', 'stay_at_home_requirements', 'income_support', 'facial_coverings', 'vaccination_policy', 'new_confirmed', 'new_deceased', 'new_recovered', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated', 'new_vaccine_doses_administered', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.70, Z=0.99
# ancestors : ['new_hospitalized_patients', 'cumulative_hospitalized_patients', 'new_intensive_care_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'school_closing', 'public_transport_closing', 'stay_at_home_requirements', 'facial_coverings', 'vaccination_policy', 'new_confirmed', 'new_deceased', 'new_recovered', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated', 'new_vaccine_doses_administered', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.71, Z=0.99
# ancestors : ['new_hospitalized_patients', 'cumulative_hospitalized_patients', 'new_intensive_care_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'public_transport_closing', 'stay_at_home_requirements', 'facial_coverings', 'vaccination_policy', 'new_confirmed', 'new_deceased', 'new_recovered', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated', 'new_vaccine_doses_administered', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.71, Z=0.99
# ancestors : ['new_hospitalized_patients', 'cumulative_hospitalized_patients', 'new_intensive_care_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'stay_at_home_requirements', 'facial_coverings', 'vaccination_policy', 'new_confirmed', 'new_deceased', 'new_recovered', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated', 'new_vaccine_doses_administered', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.71, Z=0.99
# ancestors : ['new_hospitalized_patients', 'cumulative_hospitalized_patients', 'new_intensive_care_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'stay_at_home_requirements', 'facial_coverings', 'vaccination_policy', 'new_confirmed', 'new_deceased', 'new_recovered', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.72, Z=0.99
# ancestors : ['new_hospitalized_patients', 'cumulative_hospitalized_patients', 'new_intensive_care_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'stay_at_home_requirements', 'facial_coverings', 'vaccination_policy', 'new_confirmed', 'new_deceased', 'new_recovered', 'cumulative_recovered', 'cumulative_tested', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.72, Z=0.99
# ancestors : ['new_hospitalized_patients', 'cumulative_hospitalized_patients', 'new_intensive_care_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'stay_at_home_requirements', 'facial_coverings', 'new_confirmed', 'new_deceased', 'new_recovered', 'cumulative_recovered', 'cumulative_tested', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.72, Z=0.99
# ancestors : ['new_hospitalized_patients', 'cumulative_hospitalized_patients', 'new_intensive_care_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'stay_at_home_requirements', 'facial_coverings', 'new_confirmed', 'new_deceased', 'new_recovered', 'cumulative_recovered', 'cumulative_tested', 'cumulative_persons_vaccinated', 'cumulative_persons_fully_vaccinated', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.73, Z=0.99
# ancestors : ['new_hospitalized_patients', 'cumulative_hospitalized_patients', 'new_intensive_care_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'stay_at_home_requirements', 'facial_coverings', 'new_confirmed', 'new_deceased', 'new_recovered', 'cumulative_recovered', 'cumulative_tested', 'cumulative_persons_vaccinated', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.74, Z=0.99
# ancestors : ['new_hospitalized_patients', 'cumulative_hospitalized_patients', 'new_intensive_care_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'stay_at_home_requirements', 'facial_coverings', 'new_confirmed', 'new_deceased', 'new_recovered', 'cumulative_tested', 'cumulative_persons_vaccinated', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.75, Z=0.99
# ancestors : ['new_hospitalized_patients', 'cumulative_hospitalized_patients', 'new_intensive_care_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'stay_at_home_requirements', 'new_confirmed', 'new_deceased', 'new_recovered', 'cumulative_tested', 'cumulative_persons_vaccinated', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.76, Z=0.99
# ancestors : ['new_hospitalized_patients', 'cumulative_hospitalized_patients', 'new_intensive_care_patients', 'current_intensive_care_patients', 'stay_at_home_requirements', 'new_confirmed', 'new_deceased', 'new_recovered', 'cumulative_tested', 'cumulative_persons_vaccinated', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.77, Z=0.99
# ancestors : ['new_hospitalized_patients', 'cumulative_hospitalized_patients', 'new_intensive_care_patients', 'current_intensive_care_patients', 'stay_at_home_requirements', 'new_confirmed', 'new_deceased', 'cumulative_tested', 'cumulative_persons_vaccinated', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.79, Z=1.00
# ancestors : ['new_hospitalized_patients', 'new_intensive_care_patients', 'current_intensive_care_patients', 'stay_at_home_requirements', 'new_confirmed', 'new_deceased', 'cumulative_tested', 'cumulative_persons_vaccinated', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.80, Z=1.00
# ancestors : ['new_hospitalized_patients', 'new_intensive_care_patients', 'current_intensive_care_patients', 'stay_at_home_requirements', 'new_confirmed', 'new_deceased', 'cumulative_persons_vaccinated', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.82, Z=1.00
# ancestors : ['new_hospitalized_patients', 'new_intensive_care_patients', 'current_intensive_care_patients', 'stay_at_home_requirements', 'new_confirmed', 'new_deceased', 'cumulative_persons_vaccinated']
#  n/(n+s)=0.82, Z=1.00
# ancestors : ['new_hospitalized_patients', 'new_intensive_care_patients', 'current_intensive_care_patients', 'stay_at_home_requirements', 'new_confirmed', 'new_deceased']
#  n/(n+s)=0.83, Z=1.00
# ancestors : ['new_hospitalized_patients', 'new_intensive_care_patients', 'current_intensive_care_patients', 'stay_at_home_requirements', 'new_deceased']
#  n/(n+s)=0.85, Z=1.00
# ancestors : ['new_hospitalized_patients', 'new_intensive_care_patients', 'current_intensive_care_patients', 'new_deceased']
#  n/(n+s)=0.86, Z=1.00
# ancestors : ['new_hospitalized_patients', 'current_intensive_care_patients', 'new_deceased']
#  n/(n+s)=0.87, Z=1.00
# ancestors : ['new_hospitalized_patients', 'current_intensive_care_patients']
#  n/(n+s)=0.91, Z=1.00
# ancestors : ['current_intensive_care_patients']
#  n/(n+s)=0.95, Z=1.00
# ancestors after pruning:  ['current_intensive_care_patients']
#
#
#
# inspecting new_intensive_care_patients
# linear kernel (using gamma=5.07e+02)
#  n/(n+s)=0.76, Z=0.99
# quadratic kernel (using gamma=5.07e+02)
#  n/(n+s)=0.72, Z=0.99
# new_intensive_care_patients has ancestors with quadratic kernel (n/(s+n)=0.72)
# ancestors : ['new_hospitalized_patients', 'cumulative_hospitalized_patients', 'current_hospitalized_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'school_closing', 'workplace_closing', 'cancel_public_events', 'restrictions_on_gatherings', 'public_transport_closing', 'stay_at_home_requirements', 'restrictions_on_internal_movement', 'income_support', 'facial_coverings', 'vaccination_policy', 'stringency_index', 'new_confirmed', 'new_deceased', 'new_recovered', 'new_tested', 'cumulative_confirmed', 'cumulative_recovered', 'cumulative_tested', 'new_persons_vaccinated', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated', 'new_vaccine_doses_administered', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.72, Z=0.99
# ancestors : ['new_hospitalized_patients', 'current_hospitalized_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'school_closing', 'workplace_closing', 'cancel_public_events', 'restrictions_on_gatherings', 'public_transport_closing', 'stay_at_home_requirements', 'restrictions_on_internal_movement', 'income_support', 'facial_coverings', 'vaccination_policy', 'stringency_index', 'new_confirmed', 'new_deceased', 'new_recovered', 'new_tested', 'cumulative_confirmed', 'cumulative_recovered', 'cumulative_tested', 'new_persons_vaccinated', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated', 'new_vaccine_doses_administered', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.72, Z=0.99
# ancestors : ['new_hospitalized_patients', 'current_hospitalized_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'school_closing', 'workplace_closing', 'cancel_public_events', 'public_transport_closing', 'stay_at_home_requirements', 'restrictions_on_internal_movement', 'income_support', 'facial_coverings', 'vaccination_policy', 'stringency_index', 'new_confirmed', 'new_deceased', 'new_recovered', 'new_tested', 'cumulative_confirmed', 'cumulative_recovered', 'cumulative_tested', 'new_persons_vaccinated', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated', 'new_vaccine_doses_administered', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.72, Z=0.99
# ancestors : ['new_hospitalized_patients', 'current_hospitalized_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'school_closing', 'workplace_closing', 'cancel_public_events', 'public_transport_closing', 'stay_at_home_requirements', 'restrictions_on_internal_movement', 'facial_coverings', 'vaccination_policy', 'stringency_index', 'new_confirmed', 'new_deceased', 'new_recovered', 'new_tested', 'cumulative_confirmed', 'cumulative_recovered', 'cumulative_tested', 'new_persons_vaccinated', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated', 'new_vaccine_doses_administered', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.72, Z=0.99
# ancestors : ['new_hospitalized_patients', 'current_hospitalized_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'school_closing', 'workplace_closing', 'cancel_public_events', 'public_transport_closing', 'stay_at_home_requirements', 'restrictions_on_internal_movement', 'facial_coverings', 'vaccination_policy', 'stringency_index', 'new_confirmed', 'new_deceased', 'new_recovered', 'new_tested', 'cumulative_confirmed', 'cumulative_recovered', 'new_persons_vaccinated', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated', 'new_vaccine_doses_administered', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.72, Z=0.99
# ancestors : ['new_hospitalized_patients', 'current_hospitalized_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'school_closing', 'workplace_closing', 'cancel_public_events', 'public_transport_closing', 'stay_at_home_requirements', 'restrictions_on_internal_movement', 'facial_coverings', 'vaccination_policy', 'stringency_index', 'new_confirmed', 'new_deceased', 'new_recovered', 'new_tested', 'cumulative_recovered', 'new_persons_vaccinated', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated', 'new_vaccine_doses_administered', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.73, Z=0.99
# ancestors : ['new_hospitalized_patients', 'current_hospitalized_patients', 'current_intensive_care_patients', 'school_closing', 'workplace_closing', 'cancel_public_events', 'public_transport_closing', 'stay_at_home_requirements', 'restrictions_on_internal_movement', 'facial_coverings', 'vaccination_policy', 'stringency_index', 'new_confirmed', 'new_deceased', 'new_recovered', 'new_tested', 'cumulative_recovered', 'new_persons_vaccinated', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated', 'new_vaccine_doses_administered', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.72, Z=0.99
# ancestors : ['new_hospitalized_patients', 'current_hospitalized_patients', 'current_intensive_care_patients', 'school_closing', 'workplace_closing', 'cancel_public_events', 'public_transport_closing', 'stay_at_home_requirements', 'restrictions_on_internal_movement', 'facial_coverings', 'vaccination_policy', 'stringency_index', 'new_confirmed', 'new_deceased', 'new_tested', 'cumulative_recovered', 'new_persons_vaccinated', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated', 'new_vaccine_doses_administered', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.73, Z=0.99
# ancestors : ['new_hospitalized_patients', 'current_hospitalized_patients', 'current_intensive_care_patients', 'school_closing', 'workplace_closing', 'cancel_public_events', 'public_transport_closing', 'stay_at_home_requirements', 'restrictions_on_internal_movement', 'facial_coverings', 'vaccination_policy', 'stringency_index', 'new_confirmed', 'new_deceased', 'new_tested', 'new_persons_vaccinated', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated', 'new_vaccine_doses_administered', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.73, Z=0.99
# ancestors : ['new_hospitalized_patients', 'current_hospitalized_patients', 'current_intensive_care_patients', 'school_closing', 'workplace_closing', 'cancel_public_events', 'public_transport_closing', 'stay_at_home_requirements', 'restrictions_on_internal_movement', 'facial_coverings', 'vaccination_policy', 'stringency_index', 'new_confirmed', 'new_deceased', 'new_tested', 'new_persons_vaccinated', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.73, Z=0.99
# ancestors : ['new_hospitalized_patients', 'current_hospitalized_patients', 'current_intensive_care_patients', 'school_closing', 'workplace_closing', 'cancel_public_events', 'stay_at_home_requirements', 'restrictions_on_internal_movement', 'facial_coverings', 'vaccination_policy', 'stringency_index', 'new_confirmed', 'new_deceased', 'new_tested', 'new_persons_vaccinated', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.73, Z=0.99
# ancestors : ['new_hospitalized_patients', 'current_hospitalized_patients', 'current_intensive_care_patients', 'school_closing', 'workplace_closing', 'cancel_public_events', 'stay_at_home_requirements', 'restrictions_on_internal_movement', 'facial_coverings', 'vaccination_policy', 'stringency_index', 'new_confirmed', 'new_deceased', 'new_tested', 'new_persons_vaccinated', 'cumulative_persons_vaccinated', 'cumulative_persons_fully_vaccinated', 'cumulative_vaccine_doses_administered']
#  n/(n+s)=0.73, Z=0.99
# ...
#  n/(n+s)=0.72, Z=1.00
# ancestors : ['cumulative_hospitalized_patients', 'cumulative_intensive_care_patients', 'public_transport_closing', 'income_support', 'vaccination_policy', 'new_recovered', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'new_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated']
#  n/(n+s)=0.73, Z=1.00
# ancestors : ['cumulative_hospitalized_patients', 'cumulative_intensive_care_patients', 'income_support', 'vaccination_policy', 'new_recovered', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'new_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated']
#  n/(n+s)=0.74, Z=1.00
# ancestors : ['cumulative_hospitalized_patients', 'cumulative_intensive_care_patients', 'income_support', 'vaccination_policy', 'new_recovered', 'cumulative_recovered', 'cumulative_tested', 'new_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated']
#  n/(n+s)=0.74, Z=1.00
# ancestors : ['cumulative_hospitalized_patients', 'cumulative_intensive_care_patients', 'income_support', 'vaccination_policy', 'cumulative_recovered', 'cumulative_tested', 'new_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated']
#  n/(n+s)=0.75, Z=1.00
# ancestors : ['cumulative_hospitalized_patients', 'cumulative_intensive_care_patients', 'income_support', 'vaccination_policy', 'cumulative_recovered', 'cumulative_tested', 'new_persons_vaccinated', 'new_persons_fully_vaccinated']
#  n/(n+s)=0.76, Z=1.00
# ancestors : ['cumulative_hospitalized_patients', 'income_support', 'vaccination_policy', 'cumulative_recovered', 'cumulative_tested', 'new_persons_vaccinated', 'new_persons_fully_vaccinated']
#  n/(n+s)=0.76, Z=1.00
# ancestors : ['cumulative_hospitalized_patients', 'income_support', 'cumulative_recovered', 'cumulative_tested', 'new_persons_vaccinated', 'new_persons_fully_vaccinated']
#  n/(n+s)=0.78, Z=1.00
# ancestors : ['income_support', 'cumulative_recovered', 'cumulative_tested', 'new_persons_vaccinated', 'new_persons_fully_vaccinated']
#  n/(n+s)=0.78, Z=1.00
# ancestors : ['income_support', 'cumulative_tested', 'new_persons_vaccinated', 'new_persons_fully_vaccinated']
#  n/(n+s)=0.79, Z=1.00
# ancestors : ['income_support', 'new_persons_vaccinated', 'new_persons_fully_vaccinated']
#  n/(n+s)=0.80, Z=1.00
# ancestors : ['new_persons_vaccinated', 'new_persons_fully_vaccinated']
#  n/(n+s)=0.83, Z=1.00
# ancestors : ['new_persons_fully_vaccinated']
#  n/(n+s)=0.91, Z=1.00
# ancestors after pruning:  ['new_persons_fully_vaccinated']
#
#
#
# inspecting cumulative_vaccine_doses_administered
# linear kernel (using gamma=5.07e+02)
#  n/(n+s)=0.48, Z=0.99
# quadratic kernel (using gamma=5.07e+02)
#  n/(n+s)=0.44, Z=0.99
# cumulative_vaccine_doses_administered has ancestors with quadratic kernel (n/(s+n)=0.44)
# ancestors : ['cumulative_hospitalized_patients', 'current_hospitalized_patients', 'new_intensive_care_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'school_closing', 'workplace_closing', 'cancel_public_events', 'restrictions_on_gatherings', 'public_transport_closing', 'stay_at_home_requirements', 'restrictions_on_internal_movement', 'income_support', 'facial_coverings', 'vaccination_policy', 'stringency_index', 'new_confirmed', 'new_deceased', 'new_recovered', 'new_tested', 'cumulative_confirmed', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'new_persons_vaccinated', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated', 'new_vaccine_doses_administered']
#  n/(n+s)=0.44, Z=0.99
# ancestors : ['cumulative_hospitalized_patients', 'current_hospitalized_patients', 'new_intensive_care_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'school_closing', 'workplace_closing', 'restrictions_on_gatherings', 'public_transport_closing', 'stay_at_home_requirements', 'restrictions_on_internal_movement', 'income_support', 'facial_coverings', 'vaccination_policy', 'stringency_index', 'new_confirmed', 'new_deceased', 'new_recovered', 'new_tested', 'cumulative_confirmed', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'new_persons_vaccinated', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated', 'new_vaccine_doses_administered']
#  n/(n+s)=0.44, Z=0.99
# ancestors : ['cumulative_hospitalized_patients', 'current_hospitalized_patients', 'new_intensive_care_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'school_closing', 'workplace_closing', 'restrictions_on_gatherings', 'public_transport_closing', 'stay_at_home_requirements', 'restrictions_on_internal_movement', 'income_support', 'facial_coverings', 'vaccination_policy', 'new_confirmed', 'new_deceased', 'new_recovered', 'new_tested', 'cumulative_confirmed', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'new_persons_vaccinated', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated', 'new_vaccine_doses_administered']
#  n/(n+s)=0.44, Z=0.99
# ancestors : ['cumulative_hospitalized_patients', 'current_hospitalized_patients', 'new_intensive_care_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'school_closing', 'workplace_closing', 'restrictions_on_gatherings', 'public_transport_closing', 'stay_at_home_requirements', 'restrictions_on_internal_movement', 'income_support', 'facial_coverings', 'vaccination_policy', 'new_confirmed', 'new_deceased', 'new_recovered', 'new_tested', 'cumulative_confirmed', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'new_persons_vaccinated', 'cumulative_persons_vaccinated', 'cumulative_persons_fully_vaccinated', 'new_vaccine_doses_administered']
#  n/(n+s)=0.45, Z=0.99
# ancestors : ['cumulative_hospitalized_patients', 'current_hospitalized_patients', 'new_intensive_care_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'school_closing', 'workplace_closing', 'restrictions_on_gatherings', 'public_transport_closing', 'stay_at_home_requirements', 'restrictions_on_internal_movement', 'income_support', 'facial_coverings', 'vaccination_policy', 'new_deceased', 'new_recovered', 'new_tested', 'cumulative_confirmed', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'new_persons_vaccinated', 'cumulative_persons_vaccinated', 'cumulative_persons_fully_vaccinated', 'new_vaccine_doses_administered']
#  n/(n+s)=0.45, Z=0.99
# ancestors : ['cumulative_hospitalized_patients', 'current_hospitalized_patients', 'new_intensive_care_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'school_closing', 'workplace_closing', 'restrictions_on_gatherings', 'public_transport_closing', 'stay_at_home_requirements', 'restrictions_on_internal_movement', 'income_support', 'facial_coverings', 'vaccination_policy', 'new_deceased', 'new_recovered', 'new_tested', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'new_persons_vaccinated', 'cumulative_persons_vaccinated', 'cumulative_persons_fully_vaccinated', 'new_vaccine_doses_administered']
#  n/(n+s)=0.44, Z=0.99
# ancestors : ['cumulative_hospitalized_patients', 'current_hospitalized_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'school_closing', 'workplace_closing', 'restrictions_on_gatherings', 'public_transport_closing', 'stay_at_home_requirements', 'restrictions_on_internal_movement', 'income_support', 'facial_coverings', 'vaccination_policy', 'new_deceased', 'new_recovered', 'new_tested', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'new_persons_vaccinated', 'cumulative_persons_vaccinated', 'cumulative_persons_fully_vaccinated', 'new_vaccine_doses_administered']
#  n/(n+s)=0.45, Z=0.99
# ancestors : ['cumulative_hospitalized_patients', 'current_hospitalized_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'school_closing', 'workplace_closing', 'restrictions_on_gatherings', 'public_transport_closing', 'stay_at_home_requirements', 'restrictions_on_internal_movement', 'income_support', 'facial_coverings', 'vaccination_policy', 'new_deceased', 'new_recovered', 'new_tested', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'new_persons_vaccinated', 'cumulative_persons_vaccinated', 'cumulative_persons_fully_vaccinated']
#  n/(n+s)=0.45, Z=0.99
# ancestors : ['cumulative_hospitalized_patients', 'current_hospitalized_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'school_closing', 'workplace_closing', 'restrictions_on_gatherings', 'public_transport_closing', 'stay_at_home_requirements', 'restrictions_on_internal_movement', 'income_support', 'facial_coverings', 'vaccination_policy', 'new_deceased', 'new_recovered', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'new_persons_vaccinated', 'cumulative_persons_vaccinated', 'cumulative_persons_fully_vaccinated']
#  n/(n+s)=0.46, Z=0.99
# ancestors : ['cumulative_hospitalized_patients', 'current_hospitalized_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'school_closing', 'restrictions_on_gatherings', 'public_transport_closing', 'stay_at_home_requirements', 'restrictions_on_internal_movement', 'income_support', 'facial_coverings', 'vaccination_policy', 'new_deceased', 'new_recovered', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'new_persons_vaccinated', 'cumulative_persons_vaccinated', 'cumulative_persons_fully_vaccinated']
#  n/(n+s)=0.46, Z=0.99
# ancestors : ['cumulative_hospitalized_patients', 'current_hospitalized_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'school_closing', 'restrictions_on_gatherings', 'public_transport_closing', 'stay_at_home_requirements', 'income_support', 'facial_coverings', 'vaccination_policy', 'new_deceased', 'new_recovered', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'new_persons_vaccinated', 'cumulative_persons_vaccinated', 'cumulative_persons_fully_vaccinated']
#  n/(n+s)=0.47, Z=0.99
# ancestors : ['cumulative_hospitalized_patients', 'current_hospitalized_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'restrictions_on_gatherings', 'public_transport_closing', 'stay_at_home_requirements', 'income_support', 'facial_coverings', 'vaccination_policy', 'new_deceased', 'new_recovered', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'new_persons_vaccinated', 'cumulative_persons_vaccinated', 'cumulative_persons_fully_vaccinated']
#  n/(n+s)=0.47, Z=0.99
# ancestors : ['cumulative_hospitalized_patients', 'current_hospitalized_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'restrictions_on_gatherings', 'public_transport_closing', 'stay_at_home_requirements', 'income_support', 'facial_coverings', 'vaccination_policy', 'new_deceased', 'new_recovered', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'cumulative_persons_vaccinated', 'cumulative_persons_fully_vaccinated']
#  n/(n+s)=0.48, Z=0.99
# ancestors : ['cumulative_hospitalized_patients', 'current_hospitalized_patients', 'cumulative_intensive_care_patients', 'current_intensive_care_patients', 'restrictions_on_gatherings', 'public_transport_closing', 'stay_at_home_requirements', 'income_support', 'facial_coverings', 'vaccination_policy', 'new_recovered', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'cumulative_persons_vaccinated', 'cumulative_persons_fully_vaccinated']
#  n/(n+s)=0.48, Z=1.00
# ancestors : ['cumulative_hospitalized_patients', 'current_hospitalized_patients', 'cumulative_intensive_care_patients', 'restrictions_on_gatherings', 'public_transport_closing', 'stay_at_home_requirements', 'income_support', 'facial_coverings', 'vaccination_policy', 'new_recovered', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'cumulative_persons_vaccinated', 'cumulative_persons_fully_vaccinated']
#  n/(n+s)=0.49, Z=1.00
# ancestors : ['cumulative_hospitalized_patients', 'current_hospitalized_patients', 'cumulative_intensive_care_patients', 'public_transport_closing', 'stay_at_home_requirements', 'income_support', 'facial_coverings', 'vaccination_policy', 'new_recovered', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'cumulative_persons_vaccinated', 'cumulative_persons_fully_vaccinated']
#  n/(n+s)=0.50, Z=1.00
# ancestors : ['cumulative_hospitalized_patients', 'cumulative_intensive_care_patients', 'public_transport_closing', 'stay_at_home_requirements', 'income_support', 'facial_coverings', 'vaccination_policy', 'new_recovered', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'cumulative_persons_vaccinated', 'cumulative_persons_fully_vaccinated']
#  n/(n+s)=0.51, Z=1.00
# ancestors : ['cumulative_hospitalized_patients', 'cumulative_intensive_care_patients', 'public_transport_closing', 'stay_at_home_requirements', 'facial_coverings', 'vaccination_policy', 'new_recovered', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'cumulative_persons_vaccinated', 'cumulative_persons_fully_vaccinated']
#  n/(n+s)=0.53, Z=1.00
# ancestors : ['cumulative_hospitalized_patients', 'cumulative_intensive_care_patients', 'stay_at_home_requirements', 'facial_coverings', 'vaccination_policy', 'new_recovered', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'cumulative_persons_vaccinated', 'cumulative_persons_fully_vaccinated']
#  n/(n+s)=0.55, Z=1.00
# ancestors : ['cumulative_intensive_care_patients', 'stay_at_home_requirements', 'facial_coverings', 'vaccination_policy', 'new_recovered', 'cumulative_deceased', 'cumulative_recovered', 'cumulative_tested', 'cumulative_persons_vaccinated', 'cumulative_persons_fully_vaccinated']
#  n/(n+s)=0.56, Z=1.00
# ancestors : ['cumulative_intensive_care_patients', 'stay_at_home_requirements', 'facial_coverings', 'vaccination_policy', 'new_recovered', 'cumulative_recovered', 'cumulative_tested', 'cumulative_persons_vaccinated', 'cumulative_persons_fully_vaccinated']
#  n/(n+s)=0.57, Z=1.00
# ancestors : ['cumulative_intensive_care_patients', 'stay_at_home_requirements', 'facial_coverings', 'vaccination_policy', 'cumulative_recovered', 'cumulative_tested', 'cumulative_persons_vaccinated', 'cumulative_persons_fully_vaccinated']
#  n/(n+s)=0.59, Z=1.00
# ancestors : ['cumulative_intensive_care_patients', 'stay_at_home_requirements', 'vaccination_policy', 'cumulative_recovered', 'cumulative_tested', 'cumulative_persons_vaccinated', 'cumulative_persons_fully_vaccinated']
#  n/(n+s)=0.62, Z=1.00
# ancestors : ['cumulative_intensive_care_patients', 'stay_at_home_requirements', 'vaccination_policy', 'cumulative_recovered', 'cumulative_persons_vaccinated', 'cumulative_persons_fully_vaccinated']
#  n/(n+s)=0.65, Z=1.00
# ancestors : ['cumulative_intensive_care_patients', 'stay_at_home_requirements', 'cumulative_recovered', 'cumulative_persons_vaccinated', 'cumulative_persons_fully_vaccinated']
#  n/(n+s)=0.68, Z=1.00
# ancestors : ['cumulative_intensive_care_patients', 'stay_at_home_requirements', 'cumulative_persons_vaccinated', 'cumulative_persons_fully_vaccinated']
#  n/(n+s)=0.72, Z=1.00
# ancestors : ['stay_at_home_requirements', 'cumulative_persons_vaccinated', 'cumulative_persons_fully_vaccinated']
#  n/(n+s)=0.77, Z=1.00
# ancestors : ['cumulative_persons_vaccinated', 'cumulative_persons_fully_vaccinated']
#  n/(n+s)=0.83, Z=1.00
# ancestors : ['cumulative_persons_vaccinated']
#  n/(n+s)=0.91, Z=1.00
# ancestors after pruning:  ['cumulative_persons_vaccinated']

# %%
import pickle

with open('full_covid_graph.pickle', 'rb') as f:  # notice the r instead of w
    G_loaded = pickle.load(f)

# %%
def plot_a_network(G,type_label=True):
    pos=nx.kamada_kawai_layout(G, G.nodes())
    nx.draw(G, with_labels=True, pos=pos, node_size=600, font_size=8, alpha=0.6)
    if type_label:
        nx.draw_networkx_edge_labels(G,pos,edge_labels=nx.get_edge_attributes(G,'type'))
    x_values, y_values = zip(*pos.values())
    x_max = max(x_values)
    x_min = min(x_values)
    x_margin = (x_max - x_min) * 0.25
    plt.xlim(x_min - x_margin, x_max + x_margin)

# %%
plot_a_network(G_loaded,False)

# %%
plot_a_network(nx.ego_graph(graph_discovery.G.reverse(),'new_persons_fully_vaccinated',undirected=False,radius=2).reverse())

# %%
plot_a_network(nx.ego_graph(graph_discovery.G.reverse(),'new_tested',undirected=False,radius=1).reverse(),False)

# %%
G_gov=graph_discovery.G.subgraph([
       'school_closing', 'workplace_closing', 'cancel_public_events',
       'restrictions_on_gatherings', 'public_transport_closing',
       'stay_at_home_requirements', 'restrictions_on_internal_movement',
       'income_support', 'facial_coverings', 'vaccination_policy',
       'stringency_index'])
plot_a_network(G_gov,False)

# %% [markdown]
# # Delete redundant information

# %%
reduced_names = ['new_hospitalized_patients',
       'current_hospitalized_patients','current_intensive_care_patients',
       'restrictions_on_internal_movement', 'new_confirmed', 'new_deceased',
       'new_tested', 
       'new_vaccine_doses_administered','facial_coverings', 'vaccination_policy',
       'stringency_index']

# %%
X_reduced=df[reduced_names].to_numpy()
X_reduced=(X_reduced-onp.mean(X_reduced,axis=0))/onp.std(X_reduced,axis=0)

# %%
modes_reduced=ModeContainer.make_container(
    X_reduced.T,
    onp.array(reduced_names),
    {'name':'linear','beta':0.1,'type':'individual','interpolatory':False,'default':True},
    {'name':'quadratic','beta':0.1,'type':'pairwise','interpolatory':False,'default':True},
    {'name':'gaussian','beta':0.1,'type':'combinatorial','interpolatory':True,'default':True,'l':1},
)

graph_discovery_reduced=GraphDiscoveryNew(X_reduced.T,onp.array(reduced_names),modes_reduced)
for node in graph_discovery_reduced.names:
    print(f'inspecting {node}')
    graph_discovery_reduced.find_ancestors(
        node,
        gamma='auto',
    )
    print('\n')
# Out:
# inspecting new_hospitalized_patients
# linear kernel (using gamma=5.49e+01)
#  n/(n+s)=0.54, Z=0.99
# quadratic kernel (using gamma=1.53e+01)
#  n/(n+s)=0.52, Z=0.98
# gaussian kernel (using gamma=6.51e-01)
#  n/(n+s)=0.67, Z=0.80
# new_hospitalized_patients has ancestors with quadratic kernel (n/(s+n)=0.52)
# ancestors : ['current_hospitalized_patients', 'current_intensive_care_patients', 'restrictions_on_internal_movement', 'new_confirmed', 'new_deceased', 'new_tested', 'new_vaccine_doses_administered', 'facial_coverings', 'vaccination_policy']
#  n/(n+s)=0.51, Z=0.98
# ancestors : ['current_hospitalized_patients', 'current_intensive_care_patients', 'new_confirmed', 'new_deceased', 'new_tested', 'new_vaccine_doses_administered', 'facial_coverings', 'vaccination_policy']
#  n/(n+s)=0.53, Z=0.98
# ancestors : ['current_hospitalized_patients', 'new_confirmed', 'new_deceased', 'new_tested', 'new_vaccine_doses_administered', 'facial_coverings', 'vaccination_policy']
#  n/(n+s)=0.54, Z=0.99
# ancestors : ['current_hospitalized_patients', 'new_confirmed', 'new_deceased', 'new_tested', 'facial_coverings', 'vaccination_policy']
#  n/(n+s)=0.53, Z=0.99
# ancestors : ['current_hospitalized_patients', 'new_confirmed', 'new_deceased', 'new_tested', 'vaccination_policy']
#  n/(n+s)=0.54, Z=0.99
# ancestors : ['current_hospitalized_patients', 'new_confirmed', 'new_deceased', 'new_tested']
#  n/(n+s)=0.53, Z=0.99
# ancestors : ['current_hospitalized_patients', 'new_deceased', 'new_tested']
#  n/(n+s)=0.55, Z=0.99
# ancestors : ['current_hospitalized_patients', 'new_deceased']
#  n/(n+s)=0.75, Z=1.00
# ancestors : ['new_deceased']
#  n/(n+s)=0.72, Z=1.00
# ancestors after pruning:  ['new_deceased']
#
#
#
# inspecting current_hospitalized_patients
# linear kernel (using gamma=4.48e+01)
#  n/(n+s)=0.55, Z=0.99
# quadratic kernel (using gamma=1.03e+01)
#  n/(n+s)=0.46, Z=0.98
# gaussian kernel (using gamma=9.47e-01)
#  n/(n+s)=0.47, Z=0.78
# current_hospitalized_patients has ancestors with quadratic kernel (n/(s+n)=0.46)
# ancestors : ['new_hospitalized_patients', 'current_intensive_care_patients', 'new_confirmed', 'new_deceased', 'new_tested', 'new_vaccine_doses_administered', 'facial_coverings', 'vaccination_policy', 'stringency_index']
#  n/(n+s)=0.45, Z=0.98
# ancestors : ['new_hospitalized_patients', 'current_intensive_care_patients', 'new_confirmed', 'new_deceased', 'new_tested', 'facial_coverings', 'vaccination_policy', 'stringency_index']
#  n/(n+s)=0.43, Z=0.98
# ancestors : ['new_hospitalized_patients', 'current_intensive_care_patients', 'new_confirmed', 'new_deceased', 'new_tested', 'facial_coverings', 'vaccination_policy']
#  n/(n+s)=0.52, Z=0.99
# ancestors : ['new_hospitalized_patients', 'current_intensive_care_patients', 'new_confirmed', 'new_deceased', 'new_tested', 'facial_coverings']
#  n/(n+s)=0.53, Z=0.99
# ancestors : ['new_hospitalized_patients', 'current_intensive_care_patients', 'new_confirmed', 'new_deceased', 'new_tested']
#  n/(n+s)=0.55, Z=0.99
# ancestors : ['new_hospitalized_patients', 'current_intensive_care_patients', 'new_deceased', 'new_tested']
#  n/(n+s)=0.60, Z=0.99
# ancestors : ['new_hospitalized_patients', 'current_intensive_care_patients', 'new_deceased']
#  n/(n+s)=0.79, Z=0.99
# ancestors : ['new_hospitalized_patients', 'current_intensive_care_patients']
#  n/(n+s)=0.76, Z=1.00
# ancestors : ['new_hospitalized_patients']
#  n/(n+s)=0.81, Z=1.00
# ancestors after pruning:  ['new_hospitalized_patients', 'current_intensive_care_patients', 'new_deceased', 'new_tested']
#
#
#
# inspecting current_intensive_care_patients
# linear kernel (using gamma=4.81e+01)
#  n/(n+s)=0.60, Z=0.99
# quadratic kernel (using gamma=8.01e+00)
#  n/(n+s)=0.41, Z=0.98
# gaussian kernel (using gamma=9.33e-01)
#  n/(n+s)=0.35, Z=0.79
# current_intensive_care_patients has ancestors with gaussian kernel (n/(s+n)=0.35)
# ancestors : ['new_hospitalized_patients', 'current_hospitalized_patients', 'new_confirmed', 'new_deceased', 'new_tested', 'new_vaccine_doses_administered', 'facial_coverings', 'vaccination_policy', 'stringency_index']
#  n/(n+s)=0.39, Z=0.79
# ancestors : ['new_hospitalized_patients', 'current_hospitalized_patients', 'new_confirmed', 'new_deceased', 'new_tested', 'facial_coverings', 'vaccination_policy', 'stringency_index']
#  n/(n+s)=0.43, Z=0.81
# ancestors : ['new_hospitalized_patients', 'current_hospitalized_patients', 'new_confirmed', 'new_deceased', 'facial_coverings', 'vaccination_policy', 'stringency_index']
#  n/(n+s)=0.55, Z=0.84
# ancestors : ['new_hospitalized_patients', 'current_hospitalized_patients', 'new_confirmed', 'new_deceased', 'vaccination_policy', 'stringency_index']
#  n/(n+s)=0.60, Z=0.85
# ancestors : ['new_hospitalized_patients', 'current_hospitalized_patients', 'new_confirmed', 'new_deceased', 'stringency_index']
#  n/(n+s)=0.78, Z=0.87
# ancestors : ['new_hospitalized_patients', 'current_hospitalized_patients', 'new_deceased', 'stringency_index']
#  n/(n+s)=0.81, Z=0.89
# gamma too small for set gamma_min (8.86e-11) needed for numerical stability, using 1.00e-09 instead
# This can either mean that the noise is very low or there is an issue in the automatic determination of gamma. To change the tolerance, change parameter gamma_min
# ancestors : ['current_hospitalized_patients', 'new_deceased', 'stringency_index']
#  n/(n+s)=0.90, Z=0.94
# gamma too small for set gamma_min (3.84e-15) needed for numerical stability, using 1.00e-09 instead
# This can either mean that the noise is very low or there is an issue in the automatic determination of gamma. To change the tolerance, change parameter gamma_min
# ancestors : ['current_hospitalized_patients', 'stringency_index']
#  n/(n+s)=0.93, Z=0.99
# auto gamma through variance maximisation seem to have failed (found gamma=5.02e-17). Relying on eigenvalue median instead (gamma=-6.83e-32)
# gamma too small for set gamma_min (-6.83e-32) needed for numerical stability, using 1.00e-09 instead
# This can either mean that the noise is very low or there is an issue in the automatic determination of gamma. To change the tolerance, change parameter gamma_min
# ancestors : ['stringency_index']
#  n/(n+s)=0.99, Z=1.00
# ancestors after pruning:  ['new_hospitalized_patients', 'current_hospitalized_patients', 'new_confirmed', 'new_deceased', 'vaccination_policy', 'stringency_index']
#
#
#
# inspecting restrictions_on_internal_movement
# linear kernel (using gamma=8.16e+01)
#  n/(n+s)=0.71, Z=0.99
# quadratic kernel (using gamma=9.85e+00)
#  n/(n+s)=0.60, Z=0.98
# gaussian kernel (using gamma=1.18e+00)
#  n/(n+s)=0.17, Z=0.78
# restrictions_on_internal_movement has ancestors with gaussian kernel (n/(s+n)=0.17)
# ancestors : ['new_hospitalized_patients', 'current_hospitalized_patients', 'current_intensive_care_patients', 'new_confirmed', 'new_tested', 'new_vaccine_doses_administered', 'facial_coverings', 'vaccination_policy', 'stringency_index']
#  n/(n+s)=0.24, Z=0.80
# ancestors : ['current_hospitalized_patients', 'current_intensive_care_patients', 'new_confirmed', 'new_tested', 'new_vaccine_doses_administered', 'facial_coverings', 'vaccination_policy', 'stringency_index']
#  n/(n+s)=0.33, Z=0.83
# ancestors : ['current_hospitalized_patients', 'current_intensive_care_patients', 'new_tested', 'new_vaccine_doses_administered', 'facial_coverings', 'vaccination_policy', 'stringency_index']
#  n/(n+s)=0.34, Z=0.85
# ancestors : ['current_hospitalized_patients', 'current_intensive_care_patients', 'new_tested', 'new_vaccine_doses_administered', 'vaccination_policy', 'stringency_index']
#  n/(n+s)=0.29, Z=0.85
# ancestors : ['current_hospitalized_patients', 'current_intensive_care_patients', 'new_tested', 'vaccination_policy', 'stringency_index']
#  n/(n+s)=0.17, Z=0.89
# ancestors : ['current_hospitalized_patients', 'current_intensive_care_patients', 'new_tested', 'stringency_index']
#  n/(n+s)=0.46, Z=0.89
# gamma too small for set gamma_min (2.44e-15) needed for numerical stability, using 1.00e-09 instead
# This can either mean that the noise is very low or there is an issue in the automatic determination of gamma. To change the tolerance, change parameter gamma_min
# ancestors : ['current_hospitalized_patients', 'current_intensive_care_patients', 'stringency_index']
#  n/(n+s)=0.44, Z=0.97
# gamma too small for set gamma_min (3.84e-15) needed for numerical stability, using 1.00e-09 instead
# This can either mean that the noise is very low or there is an issue in the automatic determination of gamma. To change the tolerance, change parameter gamma_min
# ancestors : ['current_hospitalized_patients', 'stringency_index']
#  n/(n+s)=0.89, Z=0.99
# auto gamma through variance maximisation seem to have failed (found gamma=5.02e-17). Relying on eigenvalue median instead (gamma=-6.83e-32)
# gamma too small for set gamma_min (-6.83e-32) needed for numerical stability, using 1.00e-09 instead
# This can either mean that the noise is very low or there is an issue in the automatic determination of gamma. To change the tolerance, change parameter gamma_min
# ancestors : ['stringency_index']
#  n/(n+s)=0.97, Z=1.00
# ancestors after pruning:  ['current_hospitalized_patients', 'current_intensive_care_patients', 'stringency_index']
#
#
#
# inspecting new_confirmed
# linear kernel (using gamma=1.76e+02)
#  n/(n+s)=0.85, Z=0.99
# quadratic kernel (using gamma=4.96e+01)
#  n/(n+s)=0.77, Z=0.98
# gaussian kernel (using gamma=7.90e-01)
#  n/(n+s)=0.56, Z=0.79
# new_confirmed has ancestors with gaussian kernel (n/(s+n)=0.56)
# ancestors : ['new_hospitalized_patients', 'current_hospitalized_patients', 'current_intensive_care_patients', 'new_deceased', 'new_tested', 'new_vaccine_doses_administered', 'facial_coverings', 'vaccination_policy', 'stringency_index']
#  n/(n+s)=0.57, Z=0.79
# ancestors : ['new_hospitalized_patients', 'current_hospitalized_patients', 'current_intensive_care_patients', 'new_deceased', 'new_tested', 'new_vaccine_doses_administered', 'facial_coverings', 'stringency_index']
#  n/(n+s)=0.58, Z=0.80
# ancestors : ['new_hospitalized_patients', 'current_hospitalized_patients', 'current_intensive_care_patients', 'new_deceased', 'new_tested', 'facial_coverings', 'stringency_index']
#  n/(n+s)=0.63, Z=0.82
# ancestors : ['new_hospitalized_patients', 'current_hospitalized_patients', 'current_intensive_care_patients', 'new_deceased', 'new_tested', 'stringency_index']
#  n/(n+s)=0.59, Z=0.83
# ancestors : ['new_hospitalized_patients', 'current_hospitalized_patients', 'current_intensive_care_patients', 'new_deceased', 'new_tested']
#  n/(n+s)=0.64, Z=0.85
# ancestors : ['new_hospitalized_patients', 'current_hospitalized_patients', 'current_intensive_care_patients', 'new_tested']
#  n/(n+s)=0.79, Z=0.88
# ancestors : ['new_hospitalized_patients', 'current_intensive_care_patients', 'new_tested']
#  n/(n+s)=0.90, Z=0.92
# gamma too small for set gamma_min (3.16e-15) needed for numerical stability, using 1.00e-09 instead
# This can either mean that the noise is very low or there is an issue in the automatic determination of gamma. To change the tolerance, change parameter gamma_min
# ancestors : ['new_hospitalized_patients', 'current_intensive_care_patients']
#  n/(n+s)=0.98, Z=0.98
# auto gamma through variance maximisation seem to have failed (found gamma=1.50e-15). Relying on eigenvalue median instead (gamma=-1.27e-16)
# gamma too small for set gamma_min (-1.27e-16) needed for numerical stability, using 1.00e-09 instead
# This can either mean that the noise is very low or there is an issue in the automatic determination of gamma. To change the tolerance, change parameter gamma_min
# ancestors : ['current_intensive_care_patients']
#  n/(n+s)=0.99, Z=1.00
# ancestors after pruning:  ['new_hospitalized_patients', 'current_hospitalized_patients', 'current_intensive_care_patients', 'new_deceased', 'new_tested']
#
#
#
# inspecting new_deceased
# linear kernel (using gamma=9.62e+01)
#  n/(n+s)=0.69, Z=0.99
# quadratic kernel (using gamma=5.91e+01)
#  n/(n+s)=0.67, Z=0.98
# gaussian kernel (using gamma=5.64e-01)
#  n/(n+s)=0.72, Z=0.80
# new_deceased has ancestors with quadratic kernel (n/(s+n)=0.67)
# ancestors : ['new_hospitalized_patients', 'current_hospitalized_patients', 'current_intensive_care_patients', 'new_confirmed', 'new_tested', 'new_vaccine_doses_administered', 'facial_coverings', 'vaccination_policy', 'stringency_index']
#  n/(n+s)=0.67, Z=0.99
# ancestors : ['new_hospitalized_patients', 'current_hospitalized_patients', 'current_intensive_care_patients', 'new_confirmed', 'new_tested', 'facial_coverings', 'vaccination_policy', 'stringency_index']
#  n/(n+s)=0.66, Z=0.99
# ancestors : ['new_hospitalized_patients', 'current_hospitalized_patients', 'current_intensive_care_patients', 'new_confirmed', 'new_tested', 'facial_coverings', 'vaccination_policy']
#  n/(n+s)=0.66, Z=0.99
# ancestors : ['new_hospitalized_patients', 'current_hospitalized_patients', 'current_intensive_care_patients', 'new_tested', 'facial_coverings', 'vaccination_policy']
#  n/(n+s)=0.67, Z=0.99
# ancestors : ['new_hospitalized_patients', 'current_hospitalized_patients', 'current_intensive_care_patients', 'facial_coverings', 'vaccination_policy']
#  n/(n+s)=0.68, Z=0.99
# ancestors : ['new_hospitalized_patients', 'current_hospitalized_patients', 'current_intensive_care_patients', 'vaccination_policy']
#  n/(n+s)=0.69, Z=0.99
# ancestors : ['new_hospitalized_patients', 'current_hospitalized_patients', 'current_intensive_care_patients']
#  n/(n+s)=0.73, Z=0.99
# ancestors : ['new_hospitalized_patients', 'current_hospitalized_patients']
#  n/(n+s)=0.75, Z=1.00
# ancestors : ['new_hospitalized_patients']
#  n/(n+s)=0.80, Z=1.00
# ancestors after pruning:  ['new_hospitalized_patients']
#
#
#
# inspecting new_tested
# linear kernel (using gamma=1.56e+02)
#  n/(n+s)=0.87, Z=0.99
# quadratic kernel (using gamma=5.09e+01)
#  n/(n+s)=0.75, Z=0.98
# gaussian kernel (using gamma=5.41e-01)
#  n/(n+s)=0.68, Z=0.80
# new_tested has ancestors with gaussian kernel (n/(s+n)=0.68)
# ancestors : ['new_hospitalized_patients', 'current_hospitalized_patients', 'current_intensive_care_patients', 'restrictions_on_internal_movement', 'new_confirmed', 'new_deceased', 'new_vaccine_doses_administered', 'facial_coverings', 'stringency_index']
#  n/(n+s)=0.68, Z=0.80
# ancestors : ['new_hospitalized_patients', 'current_hospitalized_patients', 'current_intensive_care_patients', 'new_confirmed', 'new_deceased', 'new_vaccine_doses_administered', 'facial_coverings', 'stringency_index']
#  n/(n+s)=0.68, Z=0.80
# ancestors : ['new_hospitalized_patients', 'current_hospitalized_patients', 'current_intensive_care_patients', 'new_confirmed', 'new_deceased', 'new_vaccine_doses_administered', 'stringency_index']
#  n/(n+s)=0.68, Z=0.81
# ancestors : ['new_hospitalized_patients', 'current_hospitalized_patients', 'current_intensive_care_patients', 'new_confirmed', 'new_deceased', 'new_vaccine_doses_administered']
#  n/(n+s)=0.70, Z=0.83
# ancestors : ['new_hospitalized_patients', 'current_hospitalized_patients', 'current_intensive_care_patients', 'new_confirmed', 'new_vaccine_doses_administered']
#  n/(n+s)=0.77, Z=0.86
# ancestors : ['new_hospitalized_patients', 'current_hospitalized_patients', 'current_intensive_care_patients', 'new_vaccine_doses_administered']
#  n/(n+s)=0.86, Z=0.88
# ancestors : ['new_hospitalized_patients', 'current_hospitalized_patients', 'new_vaccine_doses_administered']
#  n/(n+s)=0.92, Z=0.92
# gamma too small for set gamma_min (4.99e-15) needed for numerical stability, using 1.00e-09 instead
# This can either mean that the noise is very low or there is an issue in the automatic determination of gamma. To change the tolerance, change parameter gamma_min
# ancestors : ['new_hospitalized_patients', 'current_hospitalized_patients']
#  n/(n+s)=0.97, Z=0.98
# auto gamma through variance maximisation seem to have failed (found gamma=4.82e-15). Relying on eigenvalue median instead (gamma=-9.38e-17)
# gamma too small for set gamma_min (-9.38e-17) needed for numerical stability, using 1.00e-09 instead
# This can either mean that the noise is very low or there is an issue in the automatic determination of gamma. To change the tolerance, change parameter gamma_min
# ancestors : ['current_hospitalized_patients']
#  n/(n+s)=1.00, Z=1.00
# ancestors after pruning:  ['new_hospitalized_patients', 'current_hospitalized_patients', 'current_intensive_care_patients', 'new_confirmed', 'new_vaccine_doses_administered']
#
#
#
# inspecting new_vaccine_doses_administered
# linear kernel (using gamma=2.17e+02)
#  n/(n+s)=0.93, Z=1.00
# quadratic kernel (using gamma=3.99e+01)
#  n/(n+s)=0.66, Z=0.98
# gaussian kernel (using gamma=6.65e-01)
#  n/(n+s)=0.72, Z=0.80
# new_vaccine_doses_administered has ancestors with quadratic kernel (n/(s+n)=0.66)
# ancestors : ['new_hospitalized_patients', 'current_hospitalized_patients', 'restrictions_on_internal_movement', 'new_confirmed', 'new_deceased', 'new_tested', 'facial_coverings', 'vaccination_policy', 'stringency_index']
#  n/(n+s)=0.67, Z=0.98
# ancestors : ['new_hospitalized_patients', 'current_hospitalized_patients', 'restrictions_on_internal_movement', 'new_deceased', 'new_tested', 'facial_coverings', 'vaccination_policy', 'stringency_index']
#  n/(n+s)=0.67, Z=0.99
# ancestors : ['new_hospitalized_patients', 'current_hospitalized_patients', 'restrictions_on_internal_movement', 'new_tested', 'facial_coverings', 'vaccination_policy', 'stringency_index']
#  n/(n+s)=0.67, Z=0.99
# ancestors : ['new_hospitalized_patients', 'current_hospitalized_patients', 'restrictions_on_internal_movement', 'facial_coverings', 'vaccination_policy', 'stringency_index']
#  n/(n+s)=0.73, Z=0.99
# ancestors : ['current_hospitalized_patients', 'restrictions_on_internal_movement', 'facial_coverings', 'vaccination_policy', 'stringency_index']
#  n/(n+s)=0.72, Z=0.99
# ancestors : ['current_hospitalized_patients', 'restrictions_on_internal_movement', 'vaccination_policy', 'stringency_index']
#  n/(n+s)=0.76, Z=0.99
# ancestors : ['current_hospitalized_patients', 'restrictions_on_internal_movement', 'stringency_index']
#  n/(n+s)=0.82, Z=1.00
# ancestors : ['current_hospitalized_patients', 'restrictions_on_internal_movement']
#  n/(n+s)=0.87, Z=1.00
# ancestors : ['current_hospitalized_patients']
#  n/(n+s)=0.98, Z=1.00
# ancestors after pruning:  ['current_hospitalized_patients', 'restrictions_on_internal_movement']
#
#
#
# inspecting facial_coverings
# linear kernel (using gamma=8.39e+01)
#  n/(n+s)=0.70, Z=0.99
# quadratic kernel (using gamma=4.12e+01)
#  n/(n+s)=0.63, Z=0.98
# gaussian kernel (using gamma=9.59e-01)
#  n/(n+s)=0.75, Z=0.78
# facial_coverings has ancestors with quadratic kernel (n/(s+n)=0.63)
# ancestors : ['current_hospitalized_patients', 'current_intensive_care_patients', 'restrictions_on_internal_movement', 'new_confirmed', 'new_deceased', 'new_tested', 'new_vaccine_doses_administered', 'vaccination_policy', 'stringency_index']
#  n/(n+s)=0.63, Z=0.99
# ancestors : ['current_hospitalized_patients', 'current_intensive_care_patients', 'restrictions_on_internal_movement', 'new_confirmed', 'new_tested', 'new_vaccine_doses_administered', 'vaccination_policy', 'stringency_index']
#  n/(n+s)=0.62, Z=0.99
# ancestors : ['current_hospitalized_patients', 'current_intensive_care_patients', 'restrictions_on_internal_movement', 'new_confirmed', 'new_vaccine_doses_administered', 'vaccination_policy', 'stringency_index']
#  n/(n+s)=0.63, Z=0.99
# ancestors : ['current_hospitalized_patients', 'current_intensive_care_patients', 'restrictions_on_internal_movement', 'new_vaccine_doses_administered', 'vaccination_policy', 'stringency_index']
#  n/(n+s)=0.63, Z=0.99
# ancestors : ['current_hospitalized_patients', 'current_intensive_care_patients', 'new_vaccine_doses_administered', 'vaccination_policy', 'stringency_index']
#  n/(n+s)=0.65, Z=0.99
# ancestors : ['current_hospitalized_patients', 'current_intensive_care_patients', 'vaccination_policy', 'stringency_index']
#  n/(n+s)=0.71, Z=0.99
# ancestors : ['current_intensive_care_patients', 'vaccination_policy', 'stringency_index']
#  n/(n+s)=0.74, Z=1.00
# ancestors : ['current_intensive_care_patients', 'stringency_index']
#  n/(n+s)=0.80, Z=1.00
# ancestors : ['current_intensive_care_patients']
#  n/(n+s)=0.84, Z=1.00
# ancestors after pruning:  ['current_intensive_care_patients']
#
#
#
# inspecting vaccination_policy
# linear kernel (using gamma=1.30e+02)
#  n/(n+s)=0.79, Z=0.99
# quadratic kernel (using gamma=2.51e+01)
#  n/(n+s)=0.59, Z=0.98
# gaussian kernel (using gamma=1.13e+00)
#  n/(n+s)=0.67, Z=0.78
# vaccination_policy has ancestors with quadratic kernel (n/(s+n)=0.59)
# ancestors : ['new_hospitalized_patients', 'current_hospitalized_patients', 'restrictions_on_internal_movement', 'new_confirmed', 'new_deceased', 'new_tested', 'new_vaccine_doses_administered', 'facial_coverings', 'stringency_index']
#  n/(n+s)=0.62, Z=0.98
# ancestors : ['current_hospitalized_patients', 'restrictions_on_internal_movement', 'new_confirmed', 'new_deceased', 'new_tested', 'new_vaccine_doses_administered', 'facial_coverings', 'stringency_index']
#  n/(n+s)=0.62, Z=0.98
# ancestors : ['current_hospitalized_patients', 'restrictions_on_internal_movement', 'new_confirmed', 'new_deceased', 'new_vaccine_doses_administered', 'facial_coverings', 'stringency_index']
#  n/(n+s)=0.62, Z=0.99
# ancestors : ['current_hospitalized_patients', 'restrictions_on_internal_movement', 'new_deceased', 'new_vaccine_doses_administered', 'facial_coverings', 'stringency_index']
#  n/(n+s)=0.63, Z=0.99
# ancestors : ['current_hospitalized_patients', 'restrictions_on_internal_movement', 'new_deceased', 'new_vaccine_doses_administered', 'facial_coverings']
#  n/(n+s)=0.63, Z=0.99
# ancestors : ['current_hospitalized_patients', 'restrictions_on_internal_movement', 'new_vaccine_doses_administered', 'facial_coverings']
#  n/(n+s)=0.61, Z=0.99
# ancestors : ['current_hospitalized_patients', 'new_vaccine_doses_administered', 'facial_coverings']
#  n/(n+s)=0.67, Z=0.99
# ancestors : ['current_hospitalized_patients', 'facial_coverings']
#  n/(n+s)=0.78, Z=1.00
# ancestors : ['facial_coverings']
#  n/(n+s)=0.81, Z=1.00
# ancestors after pruning:  ['facial_coverings']
#
#
#
# inspecting stringency_index
# linear kernel (using gamma=9.35e+01)
#  n/(n+s)=0.75, Z=0.99
# quadratic kernel (using gamma=2.83e+00)
#  n/(n+s)=0.27, Z=0.98
# gaussian kernel (using gamma=1.17e+00)
#  n/(n+s)=0.39, Z=0.78
# stringency_index has ancestors with quadratic kernel (n/(s+n)=0.27)
# ancestors : ['new_hospitalized_patients', 'current_hospitalized_patients', 'current_intensive_care_patients', 'restrictions_on_internal_movement', 'new_confirmed', 'new_tested', 'new_vaccine_doses_administered', 'facial_coverings', 'vaccination_policy']
#  n/(n+s)=0.26, Z=0.98
# ancestors : ['new_hospitalized_patients', 'current_hospitalized_patients', 'current_intensive_care_patients', 'restrictions_on_internal_movement', 'new_tested', 'new_vaccine_doses_administered', 'facial_coverings', 'vaccination_policy']
#  n/(n+s)=0.28, Z=0.98
# ancestors : ['current_hospitalized_patients', 'current_intensive_care_patients', 'restrictions_on_internal_movement', 'new_tested', 'new_vaccine_doses_administered', 'facial_coverings', 'vaccination_policy']
#  n/(n+s)=0.27, Z=0.99
# ancestors : ['current_hospitalized_patients', 'current_intensive_care_patients', 'restrictions_on_internal_movement', 'new_vaccine_doses_administered', 'facial_coverings', 'vaccination_policy']
#  n/(n+s)=0.31, Z=0.99
# ancestors : ['current_hospitalized_patients', 'current_intensive_care_patients', 'restrictions_on_internal_movement', 'new_vaccine_doses_administered', 'facial_coverings']
#  n/(n+s)=0.37, Z=0.99
# ancestors : ['current_intensive_care_patients', 'restrictions_on_internal_movement', 'new_vaccine_doses_administered', 'facial_coverings']
#  n/(n+s)=0.35, Z=0.99
# ancestors : ['restrictions_on_internal_movement', 'new_vaccine_doses_administered', 'facial_coverings']
#  n/(n+s)=0.41, Z=1.00
# ancestors : ['restrictions_on_internal_movement', 'facial_coverings']
#  n/(n+s)=0.68, Z=1.00
# ancestors : ['restrictions_on_internal_movement']
#  n/(n+s)=0.94, Z=1.00
# ancestors after pruning:  ['restrictions_on_internal_movement', 'facial_coverings']

# %%
plot_a_network(graph_discovery_reduced.G,False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/theobourdais/Library/CloudStorage/OneDrive-CaliforniaInstituteofTechnology/Caltech/Research/Computational hypergraph discovery/GraphDiscovery/COVID graph discovery_gamma=N.ipynb Cellule 19 line 1
# ----> <a href='vscode-notebook-cell:/Users/theobourdais/Library/CloudStorage/OneDrive-CaliforniaInstituteofTechnology/Caltech/Research/Computational%20hypergraph%20discovery/GraphDiscovery/COVID%20graph%20discovery_gamma%3DN.ipynb#X24sZmlsZQ%3D%3D?line=0'>1</a> plot_a_network(graph_discovery_reduced.G,False)
#
# NameError: name 'plot_a_network' is not defined
